# %% [markdown]
# # L4: Enhancing Cache Effectiveness

# %%
import sys
# !{sys.executable} -m pip install langchain_core langchain_google_genai
# Out:
# Requirement already satisfied: langchain_core in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (1.3.2)
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-4.2.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (0.8.0)
# Requirement already satisfied: packaging>=23.2.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langchain_core) (0.14.1)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain_google_genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.65.0 (from langchain_google_genai)
#   Downloading google_genai-1.74.0-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.65.0->langchain_google_genai) (4.13.0)
# Collecting google-auth<3.0.0,>=2.48.1 (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai)
#   Downloading google_auth-2.50.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.65.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.65.0->langchain_google_genai) (2.33.1)
# Collecting websockets<17.0,>=13.0.0 (from google-genai<2.0.0,>=1.65.0->langchain_google_genai)
#   Using cached websockets-16.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.65.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.65.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.65.0->langchain_google_genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai)
#   Downloading cryptography-47.0.0-cp311-abi3-macosx_10_9_universal2.whl.metadata (4.5 kB)
# Requirement already satisfied: certifi in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/I572648/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai) (2.6.3)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai)
#   Using cached cffi-2.0.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (2.6 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai)
#   Using cached pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.65.0->langchain_google_genai)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Downloading langchain_google_genai-4.2.2-py3-none-any.whl (67 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-1.74.0-py3-none-any.whl (790 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 790.4/790.4 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading google_auth-2.50.0-py3-none-any.whl (246 kB)
# Using cached websockets-16.0-cp312-cp312-macosx_10_13_x86_64.whl (175 kB)
# Downloading cryptography-47.0.0-cp311-abi3-macosx_10_9_universal2.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 14.1 MB/s eta 0:00:00a 0:00:01
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached cffi-2.0.0-cp312-cp312-macosx_10_13_x86_64.whl (185 kB)
# Using cached pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: filetype, websockets, pycparser, pyasn1, pyasn1-modules, cffi, cryptography, google-auth, google-genai, langchain_google_genai
# Successfully installed cffi-2.0.0 cryptography-47.0.0 filetype-1.2.0 google-auth-2.50.0 google-genai-1.74.0 langchain_google_genai-4.2.2 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 websockets-16.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from cache.cross_encoder import CrossEncoder
from cache.faq_data_container import FAQDataContainer
from cache.llm_evaluator import LLMEvaluator
from cache.wrapper import SemanticCacheWrapper
from cache.evals import CacheEvaluator
from cache.config import config

# Set up plotting style
plt.style.use("default")
sns.set_palette("husl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       4 import seaborn as sns
#       5
#       6 from cache.cross_encoder import CrossEncoder
#       7 from cache.faq_data_container import FAQDataContainer
# ----> 8 from cache.llm_evaluator import LLMEvaluator
#       9 from cache.wrapper import SemanticCacheWrapper
#      10 from cache.evals import CacheEvaluator
#      11 from cache.config import config
#
# File ~/Library/CloudStorage/OneDrive-SAPSE/Desktop/exp-gen/exp-gen/agent-learnings/evaluation/rag/semantic_cache/cache/llm_evaluator.py:12
#      10 from langchain_core.prompts import PromptTemplate
#      11 from langchain_core.runnables import Runnable
# ---> 12 from langchain_google_genai import ChatGoogleGenerativeAI
#      13 from langchain_openai import ChatOpenAI
#      14 from pydantic import BaseModel, Field
#
# ModuleNotFoundError: No module named 'langchain_google_genai'

# %% [markdown]
# ## Load data and setup cache

# %%
cache_wrapper = SemanticCacheWrapper.from_config(config)
data_container = FAQDataContainer()

test_queries = data_container.test_df["question"].tolist()

# %%
cache_wrapper.hydrate_from_df(data_container.faq_df)
cache_results = cache_wrapper.check_many(
    test_queries, distance_threshold=0.3
)

evaluator = CacheEvaluator(
    true_labels=data_container.label_cache_hits(cache_results),
    cache_results=cache_results,
)
evaluator.report_metrics()

# %% [markdown]
# ## Threshold sweep

# %%
cache_results = cache_wrapper.check_many(
    test_queries, distance_threshold=1
)
evaluator = CacheEvaluator.from_full_retrieval(
    true_labels=data_container.label_cache_hits(cache_results),
    cache_results=cache_results,
)

evaluator.report_threshold_sweep(
    metric_to_maximize="f1_score",
    metrics_to_plot=["f1_score", "precision", "recall"],
)

# %% [markdown]
# ## Cross Encoder Reranking

# %%
# Initialize cross encoder for reranking
cross_encoder = CrossEncoder("Alibaba-NLP/gte-reranker-modernbert-base")

# Register cross encoder as a reranker with the cache wrapper
cache_wrapper.register_reranker(cross_encoder.create_reranker())

# %%
# Test cross encoder directly (for demonstration)
cross_encoder.predict(
    [
        "what is the capital of China?",
        "how to implement quick sort in python?",
        "how to implement quick sort in python?",
    ],
    ["Beijing", "Introduction of quick sort", "The weather is nice today"],
)

# %%
sentences = [
    "The bank raised its interest rates.",
    "The river overflowed near the bank after heavy rain."
]

langcache_distance = cache_wrapper.pair_distance(
    sentences[0], sentences[1]
)
cross_encoder_distance = cross_encoder.pair_distance(
    sentences[0], sentences[1]
)

langcache_distance, cross_encoder_distance

# %%
cache_results = cache_wrapper.check_many(
    test_queries,
    distance_threshold=1,
    num_results=10,
    use_reranker_distance=True,
)
evaluator = CacheEvaluator.from_full_retrieval(
    true_labels=data_container.label_cache_hits(cache_results),
    cache_results=cache_results,
)

evaluator.report_threshold_sweep()

# %% [markdown]
# ## LLM Reranking in a Tiered System

# %%
from cache.config import load_openai_key

load_openai_key()

# %%
llm = LLMEvaluator.construct_with_gpt()

cache_wrapper.clear_reranker()
cache_wrapper.register_reranker(llm.create_reranker(batch_size=4))

# %%
cache_results = cache_wrapper.check_many(
    test_queries,
    distance_threshold=0.2828,
    num_results=1,
    show_progress=True,
)

# %%
evaluator = CacheEvaluator.from_full_retrieval(
    true_labels=data_container.label_cache_hits(cache_results),
    cache_results=cache_results,
)

evaluator.report_metrics()

# %% [markdown]
# ## Fuzzy Matching

# %%
def fuzzify_string(str, its=3):
    for i in range(its):
        str_list = list(str)
        i = np.random.randint(0, len(str) - 1)
        str_list[i], str_list[i + 1] = str_list[i + 1], str_list[i]
        str = "".join(str_list)
    return str

# %%
fuzzy_queries = []
valid_query_map = set()
for q in data_container.faq_df["question"].tolist():
    for dificulty in [2, 3, 4, 10, 10000]:
        new_entry = fuzzify_string(q, dificulty)
        fuzzy_queries.append(new_entry)
        valid_query_map.add((new_entry, q))

# %%
fuzzy_queries[:5]

# %%
from cache.fuzzy_cache import FuzzyCache

fuzzy_cache = FuzzyCache()
fuzzy_cache.hydrate_from_df(data_container.faq_df)
fuzzy_retrievals = fuzzy_cache.check_many(fuzzy_queries)

# %%
fuzzy_retrievals[:5]

# %%
valid_fuzzy_labeling = [
    (r.query, r.matches[0].prompt) in valid_query_map if len(r.matches) > 0 else False
    for r in fuzzy_retrievals
]

# %%
CacheEvaluator.from_full_retrieval(
    true_labels=valid_fuzzy_labeling,
    cache_results=fuzzy_retrievals,
).report_metrics(distance_threshold=0.6)

# %%
cache_wrapper.cache.clear()
